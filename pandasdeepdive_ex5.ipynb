# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                                title  year       name   type character   n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself NaN

# %%
release_dates = pd.DataFrame.from_csv('data/release_dates.csv', index_col=None,
                                      parse_dates=['date'], infer_datetime_format=True)
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 3                 #Horror  2015          USA 2015-11-20
# 4           #Lucky Number  2015          USA 2015-09-01

# %% [markdown]
# ### Make a bar plot of the months in which movies with "Christmas" in their title tend to be released in the USA.

# %%
r = release_dates
r.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 3                 #Horror  2015          USA 2015-11-20
# 4           #Lucky Number  2015          USA 2015-09-01

# %%
r = release_dates
r = r[r.country == 'USA']
r = r[r.title.str.contains('Christmas')]
r = r.groupby(r.date.dt.month).size()
r.plot.bar();

# %% [markdown]
# ### Make a bar plot of the months in which movies whose titles start with "The Hobbit" are released in the USA.

# %%
r = release_dates
r = r[r.title.str.startswith('The Hobbit')]
r = r[r.country == 'USA']
r = r.groupby(r.date.dt.month).size()
r.plot.bar();

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Romance" in their title tend to be released in the USA.

# %%
r = release_dates
r = r[r.country == 'USA']
r = r[r.title.str.contains('Romance')]
r = r.groupby(r.date.dt.dayofweek).size()
r.plot.bar();

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Action" in their title tend to be released in the USA.

# %%
r = release_dates
c = cast
r = r[r.country == 'USA']
r = r[r.title.str.contains('Action')]
r = r.groupby(r.date.dt.dayofweek).size()
r.plot.bar();

# %% [markdown]
# ### On which date was each Judi Dench movie from the 1990s released in the USA?

# %%
release_dates.head(2)
# Out:
#                    title  year  country       date
# 0  #73, Shaanthi Nivaasa  2007    India 2007-06-15
# 1                #Beings  2015  Romania 2015-01-29

# %%
cast.head(2)
# Out:
#                             title  year       name   type character   n
# 0                 Suuri illusioni  1985     Homo $  actor    Guests  22
# 1  Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself NaN

# %%
r = release_dates
c = cast
r = r[r.country == 'USA']
c = c[c.name == 'Judi Dench']
c = c[(c.year // 10 * 10) == 1990]
j = c.merge(r)
j
# Out:
#                      title  year        name     type        character   n  \
# 0                GoldenEye  1995  Judi Dench  actress                M   6
# 1                   Hamlet  1996  Judi Dench  actress           Hecuba  12
# 2             Jack & Sarah  1995  Judi Dench  actress         Margaret   3
# 3                Mrs Brown  1997  Judi Dench  actress   Queen Victoria   1
# 4      Shakespeare in Love  1998  Judi Dench  actress  Queen Elizabeth  12
# 5       Tea with Mussolini  1999  Judi Dench  actress         Arabella   2
# 6  The World Is Not Enough  1999  Judi Dench  actress                M   6
# 7      Tomorrow Never Dies  1997  Judi Dench  actress                M   9
#
#   country       date
# 0     USA 1995-11-17
# 1     USA 1996-12-25
# 2     USA 1996-03-22
# 3     USA 1997-10-03
# 4     USA 1999-01-08
# 5     USA 1999-05-14
# 6     USA 1999-11-19
# 7     USA 1997-12-19

# %% [markdown]
# ### In which months do films with Judi Dench tend to be released in the USA?

# %%
r = release_dates
c = cast
r = r[r.country == 'USA']
c = c[c.name == 'Judi Dench']
j = c.merge(r)
j.groupby(j.date.dt.month).size().plot.bar();

# %% [markdown]
# ### In which months do films with Tom Cruise tend to be released in the USA?

# %%
r = release_dates
c = cast
r = r[r.country == 'USA']
c = c[c.name == 'Tom Cruise']
j = c.merge(r)
j.groupby(j.date.dt.month).size().plot.bar();

# %%
r = release_dates
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 3                 #Horror  2015          USA 2015-11-20
# 4           #Lucky Number  2015          USA 2015-09-01

# %%
r.date.dt.dayofyear
# Out:
# 0         166
# 1          29
# 2          21
# 3         324
# 4         244
# 5          44
# 6         182
# 7         283
# 8         344
# 9         316
# 10        351
# 11         48
# 12         70
# 13         87
# 14        126
# 15        257
# 16        258
# 17        281
# 18        292
# 19         26
# 20        323
# 21        124
# 22        277
# 23        145
# 24         25
# 25         14
# 26        119
# 27        225
# 28        260
# 29          7
#          ...
# 422016    118
# 422017    118
# 422018    118
# 422019    118
# 422020    118
# 422021    118
# 422022    118
# 422023    118
# 422024    118
# 422025    118
# 422026    118
# 422027    118
# 422028    118
# 422029    118
# 422030    119
# 422031    119
# 422032    119
# 422033    119
# 422034    119
# 422035    119
# 422036    119
# 422037    119
# 422038    119
# 422039    119
# 422040    119
# 422041    119
# 422042    154
# 422043    154
# 422044    168
# 422045    175
# Name: date, dtype: int64

# %%
r = release_dates
r.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 3                 #Horror  2015          USA 2015-11-20
# 4           #Lucky Number  2015          USA 2015-09-01

# %%
# Merge

c = cast
c = c[c.name == 'Ellen Page']
c.head()
# Out:
#                      title  year        name     type      character   n
# 3036475  An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 3036476           Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 3036477         Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 3036478          Inception  2010  Ellen Page  actress        Ariadne   3
# 3036479    Into the Forest  2015  Ellen Page  actress           Nell   1

# %%
c.merge(r)
# Out:
#                      title  year        name     type      character   n  \
# 0        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 1        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 2        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 3        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 4        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 5        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 6        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 7        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 8        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1
# 9                 Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 10                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 11                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 12                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 13                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 14                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 15                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 16                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 17                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 18                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 19                Freeheld  2015  Ellen Page  actress  Stacie Andree NaN
# 20              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 21              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 22              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 23              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 24              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 25              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 26              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 27              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 28              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# 29              Hard Candy  2005  Ellen Page  actress   Hayley Stark   2
# ..                     ...   ...         ...      ...            ...  ..
# 424  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 425  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 426  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 427  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 428  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 429  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 430  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 431  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 432  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 433  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 434  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 435  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 436  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 437  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 438  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 439  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 440  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 441  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 442  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 443  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 444  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 445  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 446  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 447  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 448  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 449  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 450  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 451  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 452  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
# 453  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13
#
#                    country       date
# 0                   Sweden 2007-12-07
# 1                   Greece 2008-05-15
# 2                    Spain 2008-06-13
# 3                  Finland 2008-07-18
# 4                   Mexico 2008-08-08
# 5                   Brazil 2008-08-22
# 6                   Panama 2008-11-14
# 7                 Colombia 2009-10-16
# 8                     Peru 2010-03-18
# 9                    Italy 2015-11-05
# 10                  Israel 2015-12-03
# 11               Hong Kong 2015-12-05
# 12                   Spain 2016-01-29
# 13                  France 2016-02-10
# 14                  Taiwan 2016-02-19
# 15                      UK 2016-02-19
# 16                Portugal 2016-03-10
# 17                 Germany 2016-04-07
# 18             Netherlands 2016-04-07
# 19                   Chile 2016-06-02
# 20                     USA 2006-04-28
# 21                   Spain 2006-05-12
# 22                Portugal 2006-06-08
# 23                 Ireland 2006-06-16
# 24                      UK 2006-06-16
# 25                 Germany 2006-06-29
# 26               Australia 2006-07-06
# 27             Netherlands 2006-07-13
# 28               Singapore 2006-08-03
# 29                   Japan 2006-08-05
# ..                     ...        ...
# 424              Singapore 2006-05-25
# 425               Slovenia 2006-05-25
# 426               Thailand 2006-05-25
# 427                     UK 2006-05-25
# 428                 Brazil 2006-05-26
# 429               Bulgaria 2006-05-26
# 430                 Canada 2006-05-26
# 431               Colombia 2006-05-26
# 432                 Cyprus 2006-05-26
# 433                Denmark 2006-05-26
# 434                Estonia 2006-05-26
# 435                Iceland 2006-05-26
# 436                Ireland 2006-05-26
# 437                  Italy 2006-05-26
# 438              Lithuania 2006-05-26
# 439                 Mexico 2006-05-26
# 440                 Panama 2006-05-26
# 441                 Poland 2006-05-26
# 442                Romania 2006-05-26
# 443                  Spain 2006-05-26
# 444                 Turkey 2006-05-26
# 445                    USA 2006-05-26
# 446              Venezuela 2006-05-26
# 447                  India 2006-06-02
# 448  Republic of Macedonia 2006-06-10
# 449            South Korea 2006-06-15
# 450                 Taiwan 2006-06-16
# 451                Vietnam 2006-08-04
# 452                  China 2006-09-08
# 453                  Japan 2006-09-09
#
# [454 rows x 8 columns]

# %%
# you can merge a table with itself
